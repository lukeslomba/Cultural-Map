# %%
import requests
import folium
import pandas as pd
from geopy.geocoders import Nominatim
from flask import Flask

colors_dict = {'Organization':              'aqua',
                'Business':                 'blue',
                'Performance Venue':        'lime',
                'Gallery/Museum':           'pink', 
                'School/Education':         'gold',
                'Landmark/Public Space':    'green',
                'Event/Festival':           'red',
                'Artist(s) Studio/Workshop':'orange',
                'House of Worship':         'purple',
                'Library':                  'brown'}

for i in range(len(df)):
                
    if df.loc[i, 'Type'] in colors_dict.keys():
        df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
    else:
        df.loc[i, 'Color'] = 'gray'


def descriptionize(row):
    
    output = f"<b>{row['Name of the place/activity you wish to add to map']}</b> <br> <b>Category:</b> {row['Category - What is it?']} <br><b>Type:</b> {row['Type']} <br><b>Location:</b> {row['Location']} <br><b>Notes:</b> {row['Notes']}<br> <b>What do you love/appreciate about it?:</b><br>{row['What do you love/appreciate about it?']}"
    return output


def condense_duplicates(df):
    
    #df['Popup label'] = pd.Series(dtype='str')
    #df['Size'] = pd.Series(dtype='str')
    
    locations = []
    sizes = []
    droplist = []
    
    for i in range(len(df)):
                
            if df.loc[i, 'Type'] in colors_dict.keys():
                df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
            else:
                df.loc[i, 'Color'] = 'gray'
            
            locations.append(current_add)
            
    df['Drop?'] = droplist
    drop_indexes = df[df['Drop?'] == 'yes'].index.tolist()
    print(drop_indexes)
    df = df.drop(drop_indexes).reset_index()        

    return df


base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

#url = 'https://docs.google.com/spreadsheets/d/1EyIJRnLrWkeAJuxLVBxO2eSBMfKiQ2aHYLS3PLvQLLs/export?format=csv'
#r = requests.get(url, allow_redirects=True)

#open('responses.csv', 'wb').write(r.content)

response_df = pd.read_csv("responses.csv")

geolocator = Nominatim(user_agent="Luke's mapping app", timeout=2)

lat_list = []
long_list = []
add_list = []

for address in response_df['Location']:
    print(address)
    geo = geolocator.geocode(address)
    if geo != None:
        print(geo)
        lat = geo.latitude
        long = geo.longitude
        lat_list.append(lat)
        long_list.append(long)
        add_list.append(geo)
    else:
        lat_list.append('41.2705')
        long_list.append('-72.9470')
        add_list.append('West Haven, CT')
    
#break up large lines
    
for (columnName, columnData) in response_df.iteritems():
    for row in range(len(columnData)):
        cell = str(columnData.iloc[row])
        count = 0
        overall_count = 0
        if cell == None:
            response_df.at[row, columnName] = ' '
        for char in cell:
            if count >= 50 and char == ' ':
                newstring = cell[:overall_count] + '<br>' + cell[overall_count:]
                response_df.at[row, columnName] = newstring
                cell = newstring
                count = 0
            count +=1
            overall_count += 1
    
response_df['Latitude'] = lat_list
response_df['Longitude'] = long_list
response_df['Geolocated address'] = add_list

response_df = condense_duplicates(response_df)

for index, row in response_df.iterrows():
    
    caption_info = row['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                    radius = row['Size'], fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)


html = base_map._repr_html_()

file = open("index.html","w")
file.write(html)
file.close()
# Out:
# 14 Gilbert St West Haven, CT 06516
# 14, Gilbert Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
#
avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 300 Elm Street West Haven, CT
# 300, Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 260 Benham Hill Road
# 260, Benham Hill Road, West Haven, New Haven County, Connecticut, 06516, United States
# 201 Noble St West Haven, CT 06516
# 201, Noble Street, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 746 Campbell Ave West Haven, CT 06516
# 746, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 950 Campbell Ave West Haven, CT 06516
# Veterans Administration Medical Center, 950, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 840 Orange Ave West Haven, CT 06516
# 840, Orange Avenue, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 37 Orlando St West Haven, CT 06516
# 37, Orlando Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 104 Bluff Ave West Haven, CT 06516
# 104, Bluff Avenue, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 6 Rock Street, West Haven CT 06516
# 6, Rock Street, West Haven, New Haven County, Connecticut, 06516, United States
# 240 Platt Ave West Haven, CT 06516
# 240, Platt Avenue, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 100 West Campus Dr West Haven, CT 06516
# West Campus Drive, West Haven, New Haven County, Connecticut, 06516-4045, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 407 Campbell Ave West Haven, CT 06516
# 407, Campbell Avenue, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 243 Captain Thomas Blvd West Haven, CT, 06516
# 243, Captain Thomas Boulevard, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 84 Park Terrace Ave West Haven, CT 06516
# 84, Park Terrace Avenue, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# [7, 9, 12, 19, 24, 33, 37, 39, 46, 48, 51, 55, 56, 58, 65, 67, 68, 74, 78, 79, 90, 93, 98, 101, 102, 104, 108, 110, 115, 118, 120, 122, 124, 125, 127, 128, 132, 134, 140, 145, 147, 148, 150, 154, 160, 161, 163, 164, 166, 167]

# %%
response_df.loc[response_df['Geolocated address'] == 'West Haven, CT']
# Out:
#    index            Timestamp  \
# 4      4  10/24/2021 14:53:07
#
#   Name of the place/activity you wish to add to map  \
# 4                                       Abir Zenait
#
#                               Category - What is it?              Type  \
# 4  Literary Arts, Culinary Arts, Culture, Heritag...  School/Education
#
#                                         Location                  Notes  \
# 4  ESUMS 500 Boston Post Rd West Haven, CT 06516  can be hired to tutor
#
#    Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 4                           NaN         NaN                             NaN
#
#    ...  Email Address              What do you love/appreciate about it?  \
# 4  ...            NaN  Arabic language, cooking and culture classes a...
#
#                      Website / Social Media Profile? Latitude Longitude  \
# 4  https://www.linkedin.com/in/zenait-abir-9b9a3a95/  41.2705  -72.9470
#
#   Geolocated address                                        Popup label  Size  \
# 4     West Haven, CT  <b>Abir Zenait</b> <br> <b>Category:</b> Liter...  76.0
#
#    Color Drop?
# 4  black    no
#
# [1 rows x 25 columns]

# %%
import requests
import folium
import pandas as pd
from geopy.geocoders import Nominatim
from flask import Flask

def descriptionize(row):
    
    output = f"<b>{row['Name of the place/activity you wish to add to map']}</b> <br> <b>Category:</b> {row['Category - What is it?']} <br><b>Type:</b> {row['Type']} <br><b>Location:</b> {row['Location']} <br><b>Notes:</b> {row['Notes']}<br> <b>What do you love/appreciate about it?:</b><br>{row['What do you love/appreciate about it?']}"
    return output

response_df = pd.read_csv("responses.csv")

geolocator = Nominatim(user_agent="Luke's mapping app", timeout=2)

lat_list = []
long_list = []
add_list = []

for address in response_df['Location']:
    print(address)
    geo = geolocator.geocode(address)
    if geo != None:
        print(geo)
        lat = geo.latitude
        long = geo.longitude
        lat_list.append(lat)
        long_list.append(long)
        add_list.append(geo)
    else:
        lat_list.append('41.2705')
        long_list.append('-72.9470')
        add_list.append('West Haven, CT')
    
#break up large lines
    
for (columnName, columnData) in response_df.iteritems():
    for row in range(len(columnData)):
        cell = str(columnData.iloc[row])
        count = 0
        overall_count = 0
        if cell == None:
            response_df.at[row, columnName] = ' '
        for char in cell:
            if count >= 50 and char == ' ':
                newstring = cell[:overall_count] + '<br>' + cell[overall_count:]
                response_df.at[row, columnName] = newstring
                cell = newstring
                count = 0
            count +=1
            overall_count += 1
    
response_df['Latitude'] = lat_list
response_df['Longitude'] = long_list
response_df['Geolocated address'] = add_list

colors_dict = {'Organization':              'aqua',
                'Business':                 'blue',
                'Performance Venue':        'lime',
                'Gallery/Museum':           'pink', 
                'School/Education':         'gold',
                'Landmark/Public Space':    'green',
                'Event/Festival':           'red',
                'Artist(s) Studio/Workshop':'orange',
                'House of Worship':         'purple',
                'Library':                  'brown'}

for i in range(len(df)):
                
    if df.loc[i, 'Type'] in colors_dict.keys():
        df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
    else:
        df.loc[i, 'Color'] = 'gray'
# Out:
# 14 Gilbert St West Haven, CT 06516
# 14, Gilbert Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 245 Elm St West Haven, CT 06516
# 245, Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 676 Campbell Ave West Haven, CT 06516
# 676, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 500 Orange Ave West Haven, CT 06516
# 500, Orange Avenue, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 491 Campbell Ave West Haven, CT 06516
# 491, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 5 Forest Road, West Haven, CT 06516
# 5, Forest Road, Suburban Westville Historic District, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 5 Forest Road, West Haven, CT 06516
# 5, Forest Road, Suburban Westville Historic District, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 475 Campbell Ave West Haven, CT 06516
# 475, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 1 Church St West Haven, CT 06516
# 1, Church Street, West Haven, New Haven County, Connecticut, 06516, United States
# 184 Front Ave West Haven, CT 06516
# 184, Front Avenue, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 35 Marion Street West Haven, CT 06516
# 35, Marion Street, West Haven, New Haven County, Connecticut, 06516, United States
# 668 Jones Hill Rd West Haven, CT 06516
# 668, Jones Hill Road, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 194 Main St West Haven, CT 06516
# 194, Main Street, West Haven, New Haven County, Connecticut, 06516, United States
# 266 Captain Thomas Blvd West Haven, CT 06516
# 266, Captain Thomas Boulevard, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 14 Donna Ln West Haven, CT 06516
# 14, Donna Lane, West Haven, New Haven County, Connecticut, 06516, United States
# 67 Albion Ave. West Haven, CT 06156
# 67, Albion Avenue, West Shore, West Haven, New Haven County, Connecticut, 06516, United States
# 14 Gilbert St West Haven, CT 06516
# 14, Gilbert Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 29 Mullen Rd. West Haven, CT 06516
# 29, Mullen Road, West Shore, West Haven, New Haven County, Connecticut, 06516, United States
# Tile St West Haven, CT 06516
# Tile Street, West Haven, New Haven County, Connecticut, 06516, United States
# 98 Elm St West Haven, CT 06516
# 98, Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 221 Bull Hill Ln West Haven, CT 06516
# 221, Bull Hill Lane, West Haven, New Haven County, Connecticut, 06516, United States
# 1 Church St West Haven, CT 06516
# 1, Church Street, West Haven, New Haven County, Connecticut, 06516, United States
# 85 Chase Ln West Haven, CT 06516
# 85, Chase Lane, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 535 Campbell Ave West Haven, CT 06516
# 535, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 1 Kimberly Ave West Haven, CT 06516
# 1, Kimberly Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 870 1st Ave West Haven, CT 06516
# 870, 1st Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 311 Shingle Hill Rd West Haven, CT 06516
# 311, Shingle Hill Road, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 26 Coleman St West Haven, CT 06516
# 26, Coleman Street, West Haven, New Haven County, Connecticut, 06516, United States
# 664 3rd Ave West Haven, CT 06516
# 664, 3rd Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 54 Gilbert St West Haven, CT 06516
# 54, Gilbert Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 473 Sawmill Rd West Haven, CT 06516
# 473, Sawmill Road, West Haven, New Haven County, Connecticut, 06516, United States
# 24 Ocean Avenue, West Haven CT 06516
# 24, Ocean Avenue, West Haven, New Haven County, Connecticut, 06516, United States
#
Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 84 Park Terrace Ave West Haven, CT 06516
# 84, Park Terrace Avenue, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 727 Campbell Ave West Haven CT 06516
# 727, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 464 Campbell Ave West Haven CT 06516
# 464, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 1 Palace Street West Haven CT 06516
# 1, Palace Street, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 201 Noble St West Haven, CT 06516
# 201, Noble Street, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 227 Elm St West Haven, CT 06516
# 227, Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 541 Campbell Ave West Haven, CT 06516
# 541, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 220 White St West Haven, CT 06516
# 220, White Street, West Haven, New Haven County, Connecticut, 06516, United States
# 464 Campbell Ave West Haven CT 06516
# 464, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 1 Mcdonough Plz, West Haven, CT 06516
# West Haven High School, 1, McDonough Plaza, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 1 McDonough Plz West Haven, CT 06516
# West Haven High School, 1, McDonough Plaza, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 686 Savin Ave West Haven, CT 06516
# 686, Savin Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 6 Rock St. West Haven, CT
# 6, Rock Street, West Haven, New Haven County, Connecticut, 06516, United States
# Tile St West Haven, CT 06516
# Tile Street, West Haven, New Haven County, Connecticut, 06516, United States
# 7 North Union Ave West Haven, CT 06516
# 7, North Union Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 300 Elm Street West Haven, CT
# 300, Elm Street, West Haven, New Haven County, Connecticut, 06516, United States
# 260 Benham Hill Road
# 260, Benham Hill Road, West Haven, New Haven County, Connecticut, 06516, United States
# 201 Noble St West Haven, CT 06516
# 201, Noble Street, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 746 Campbell Ave West Haven, CT 06516
# 746, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 950 Campbell Ave West Haven, CT 06516
# Veterans Administration Medical Center, 950, Campbell Avenue, West Haven, New Haven County, Connecticut, 06516, United States
# 840 Orange Ave West Haven, CT 06516
# 840, Orange Avenue, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 37 Orlando St West Haven, CT 06516
# 37, Orlando Street, Allingtown, West Haven, New Haven County, Connecticut, 06516, United States
# 104 Bluff Ave West Haven, CT 06516
# 104, Bluff Avenue, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 6 Rock Street, West Haven CT 06516
# 6, Rock Street, West Haven, New Haven County, Connecticut, 06516, United States
# 240 Platt Ave West Haven, CT 06516
# 240, Platt Avenue, Sea Bluff, West Haven, New Haven County, Connecticut, 06516, United States
# 100 West Campus Dr West Haven, CT 06516
# West Campus Drive, West Haven, New Haven County, Connecticut, 06516-4045, United States
# 304 Center St West Haven, CT 06516
# 304, Center Street, West Haven, New Haven County, Connecticut, 06516, United States
# 407 Campbell Ave West Haven, CT 06516
# 407, Campbell Avenue, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 243 Captain Thomas Blvd West Haven, CT, 06516
# 243, Captain Thomas Boulevard, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States
# 84 Park Terrace Ave West Haven, CT 06516
# 84, Park Terrace Avenue, Savin Rock, West Haven, New Haven County, Connecticut, 06516, United States

# %%
colors_dict = {'Organization':              'aqua',
                'Business':                 'blue',
                'Performance Venue':        'lime',
                'Gallery/Museum':           'pink', 
                'School/Education':         'gold',
                'Landmark/Public Space':    'green',
                'Event/Festival':           'red',
                'Artist(s) Studio/Workshop':'orange',
                'House of Worship':         'purple',
                'Library':                  'brown'}


def descriptionize(row):
    
    output = f"<b>{row['Name of the place/activity you wish to add to map']}</b> <br> <b>Category:</b> {row['Category - What is it?']} <br><b>Type:</b> {row['Type']} <br><b>Location:</b> {row['Location']} <br><b>Notes:</b> {row['Notes']}<br> <b>What do you love/appreciate about it?:</b><br>{row['What do you love/appreciate about it?']}"
    return output

df = response_df

locations = []
sizes = []
droplist = []

for i in range(len(df)):
          
    current_add = df.loc[i, 'Geolocated address']
    number_same = len(df[df['Geolocated address'] == current_add])
    so_far = df[:i]
    num_so_far = len(so_far[so_far['Geolocated address'] == current_add])-1
            
    if num_so_far>0: 
        print(df.loc[i, 'Latitude'])
        print(float(df.loc[i, 'Latitude']))
        print(num_so_far)
        print(0.0002*(num_so_far))
        print(float(df.loc[i, 'Latitude'])+(0.00002*(num_so_far)))
        print('')
        df.loc[i, 'Latitude'] = float(df.loc[i, 'Latitude'])+(0.000002*(num_so_far))
                    
                    
    droplist.append('no')
                
    df.loc[i, 'Popup label'] = descriptionize(df.iloc[i])
                
    df.loc[i, 'Size'] = 10
                
    if df.loc[i, 'Type'] in colors_dict.keys():
        df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
    else:
        df.loc[i, 'Color'] = 'gray'
            
    locations.append(current_add)

df['Drop?'] = droplist
drop_indexes = df[df['Drop?'] == 'yes'].index.tolist()
print(drop_indexes)
df = df.drop(drop_indexes).reset_index()  

df
# Out:
# 41.2818594
# 41.2818594
# 1
# 0.0002
# 41.2818794
#
# 41.31391940000001
# 41.31391940000001
# 2
# 0.0004
# 41.31395940000001
#
# 41.27979
# 41.27979
# 1
# 0.0002
# 41.27981
#
# 41.28597939999999
# 41.28597939999999
# 3
# 0.0006000000000000001
# 41.286039399999986
#
# 41.28803939999999
# 41.28803939999999
# 4
# 0.0008
# 41.288119399999985
#
# 41.31185000000001
# 41.31185000000001
# 2
# 0.0004
# 41.311890000000005
#
# 41.2900994
# 41.2900994
# 5
# 0.001
# 41.290199400000006
#
# 41.283909999999985
# 41.283909999999985
# 3
# 0.0006000000000000001
# 41.28396999999998
#
# 41.285969999999985
# 41.285969999999985
# 4
# 0.0008
# 41.28604999999998
#
# 41.292159399999996
# 41.292159399999996
# 6
# 0.0012000000000000001
# 41.2922794
#
# 41.28803
# 41.28803
# 5
# 0.001
# 41.28813
#
# 41.294219400000024
# 41.294219400000024
# 7
# 0.0014
# 41.294359400000026
#
# 41.29008999999999
# 41.29008999999999
# 6
# 0.0012000000000000001
# 41.290209999999995
#
# 41.264007899999996
# 41.264007899999996
# 1
# 0.0002
# 41.264027899999995
#
# 41.27936
# 41.27936
# 1
# 0.0002
# 41.279379999999996
#
# 41.265853799999995
# 41.265853799999995
# 1
# 0.0002
# 41.265873799999994
#
# 41.2814329
# 41.2814329
# 1
# 0.0002
# 41.2814529
#
# 41.311420000000005
# 41.311420000000005
# 2
# 0.0004
# 41.311460000000004
#
# 41.2647224
# 41.2647224
# 1
# 0.0002
# 41.264742399999996
#
# 41.2999055
# 41.2999055
# 1
# 0.0002
# 41.2999255
#
# 41.33196550000001
# 41.33196550000001
# 2
# 0.0004
# 41.33200550000001
#
# 41.296067900000004
# 41.296067900000004
# 2
# 0.0004
# 41.2961079
#
# 41.2979138
# 41.2979138
# 2
# 0.0004
# 41.2979538
#
# 41.2800716
# 41.2800716
# 1
# 0.0002
# 41.2800916
#
# 41.296279400000024
# 41.296279400000024
# 8
# 0.0016
# 41.296439400000025
#
# 41.26812789999998
# 41.26812789999998
# 3
# 0.0006000000000000001
# 41.26818789999998
#
# 41.2702154
# 41.2702154
# 1
# 0.0002
# 41.2702354
#
# 41.29833940000002
# 41.29833940000002
# 9
# 0.0018000000000000002
# 41.29851940000002
#
# 41.2689162
# 41.2689162
# 1
# 0.0002
# 41.2689362
#
# []
#      index            Timestamp  \
# 0        0    7/9/2021 19:54:13
# 1        1  10/24/2021 16:32:03
# 2        2  10/24/2021 17:07:21
# 3        3  11/11/2021 16:13:49
# 4        4  10/24/2021 14:53:07
# ..     ...                  ...
# 163    163  10/23/2021 23:02:06
# 164    164     7/9/2021 8:32:37
# 165    165     7/9/2021 9:10:51
# 166    166    7/9/2021 19:33:26
# 167    167     7/9/2021 9:44:54
#
#      Name of the place/activity you wish to add to map  \
# 0                         14 Gilbert St Artist Studios
# 1                                  9/11 Memorial Mural
# 2    A Walk Through West Haven: Land Use Coordinati...
# 3                                 Abdul-Razak Zacharia
# 4                                          Abir Zenait
# ..                                                 ...
# 163                                   Yale West Campus
# 164                              Your Queer Plant Shop
# 165                                    Z's Corner Cafe
# 166                                   Zaneta Nicholson
# 167                                      Zohra Rawling
#
#                                 Category - What is it?  \
# 0    Visual Arts, Photography, Graphic Design/Print...
# 1                              Visual Arts, Public Art
# 2    Architecture, Culture, Heritage, Tradition, La...
# 3                Literary Arts, Children's Book Author
# 4    Literary Arts, Culinary Arts, Culture, Heritag...
# ..                                                 ...
# 163                                  Multidisciplinary
# 164  Craft/Design, Culture, Heritage, Tradition, Ho...
# 165                                      Comedy, Music
# 166  Theater Arts, Dance, Culture, Heritage, Tradit...
# 167                            Visual Arts, vaudeville
#
#                                          Type  \
# 0                   Artist(s) Studio/Workshop
# 1                       Landmark/Public Space
# 2    Walking Tour, Maps, Interpretive History
# 3                   Artist(s) Studio/Workshop
# 4                            School/Education
# ..                                        ...
# 163                          School/Education
# 164                                  Business
# 165                         Performance Venue
# 166                 Artist(s) Studio/Workshop
# 167                 Artist(s) Studio/Workshop
#
#                                           Location  \
# 0               14 Gilbert St West Haven, CT 06516
# 1                  245 Elm St West Haven, CT 06516
# 2            676 Campbell Ave West Haven, CT 06516
# 3               304 Center St West Haven, CT 06516
# 4              500 Orange Ave West Haven, CT 06516
# ..                                             ...
# 163        100 West Campus Dr West Haven, CT 06516
# 164             304 Center St West Haven, CT 06516
# 165          407 Campbell Ave West Haven, CT 06516
# 166  243 Captain Thomas Blvd West Haven, CT, 06516
# 167       84 Park Terrace Ave West Haven, CT 06516
#
#                                                  Notes  \
# 0                 Property Manager is The Hurley Group
# 1                                 restored in Nov 2020
# 2                                                  NaN
# 3    Children's Book based on growing up in public ...
# 4                                can be hired to tutor
# ..                                                 ...
# 163    hosted 220+ popup artist studios in 2018 & 2019
# 164  Founded by Anika Stewart and Georgina Marie - ...
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
#
#      Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ..                            ...         ...                             ...
# 163                           NaN         NaN                             NaN
# 164                           NaN         NaN                             NaN
# 165                           NaN         NaN                             NaN
# 166                           NaN         NaN                             NaN
# 167                           NaN         NaN                             NaN
#
#      ...         Email Address  \
# 0    ...  artswestct@gmail.com
# 1    ...                   NaN
# 2    ...                   NaN
# 3    ...                   NaN
# 4    ...                   NaN
# ..   ...                   ...
# 163  ...                   NaN
# 164  ...  artswestct@gmail.com
# 165  ...  artswestct@gmail.com
# 166  ...  artswestct@gmail.com
# 167  ...  artswestct@gmail.com
#
#                  What do you love/appreciate about it?  \
# 0    former factory setting with high ceilings enca...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Arabic language, cooking and culture classes a...
# ..                                                 ...
# 163                                                NaN
# 164   hard-to-find houseplants grown with artisanal...
# 165                     iconic rock venue for 24 years
# 166  recent grad from SCSU theater program with gre...
# 167              evidence of an eclectic creative life
#
#                        Website / Social Media Profile? Latitude Longitude  \
# 0                https://www.hurleygroup.net/portfolio  41.2974  -72.9563
# 1    https://us2.campaign-archive.com/?u=389568485a...  41.2766  -72.9504
# 2    https://digitalcommons.law.yale.edu/cgi/viewco...  41.2762  -72.9537
# 3    https://www.google.com/books/edition/The_Night...   41.273  -72.9513
# 4    https://www.linkedin.com/in/zenait-abir-9b9a3a95/  41.2905  -72.9665
# ..                                                 ...      ...       ...
# 163                       https://westcampus.yale.edu/  41.2702  -72.9866
# 164        https://www.facebook.com/yourqueerplantshop  41.2984  -72.9513
# 165  https://www.facebook.com/Zs-Corner-Cafe-617368...  41.2696  -72.9488
# 166          https://www.facebook.com/zaneta.nicholson  41.2689  -72.9465
# 167                                                NaN  41.2693   -72.954
#
#                                     Geolocated address  \
# 0    (14, Gilbert Street, Allingtown, West Haven, N...
# 1    (245, Elm Street, West Haven, New Haven County...
# 2    (676, Campbell Avenue, West Haven, New Haven C...
# 3    (304, Center Street, West Haven, New Haven Cou...
# 4    (500, Orange Avenue, Allingtown, West Haven, N...
# ..                                                 ...
# 163  (West Campus Drive, West Haven, New Haven Coun...
# 164  (304, Center Street, West Haven, New Haven Cou...
# 165  (407, Campbell Avenue, Savin Rock, West Haven,...
# 166  (243, Captain Thomas Boulevard, Savin Rock, We...
# 167  (84, Park Terrace Avenue, Savin Rock, West Hav...
#
#                                            Popup label  Size   Color Drop?
# 0    <b>14 Gilbert St Artist Studios</b> <br> <b>Ca...  10.0  orange    no
# 1    <b>9/11 Memorial Mural</b> <br> <b>Category:</...  10.0   green    no
# 2    <b>A Walk Through West Haven: Land Use Coordin...  10.0    gray    no
# 3    <b>Abdul-Razak Zacharia</b> <br> <b>Category:<...  10.0  orange    no
# 4    <b>Abir Zenait</b> <br> <b>Category:</b> Liter...  10.0    gold    no
# ..                                                 ...   ...     ...   ...
# 163  <b>Yale West Campus</b> <br> <b>Category:</b> ...  10.0    gold    no
# 164  <b>Your Queer Plant Shop</b> <br> <b>Category:...  10.0    blue    no
# 165  <b>Z's Corner Cafe</b> <br> <b>Category:</b> C...  10.0    lime    no
# 166  <b>Zaneta Nicholson</b> <br> <b>Category:</b> ...  10.0  orange    no
# 167  <b>Zohra Rawling</b> <br> <b>Category:</b> Vis...  10.0  orange    no
#
# [168 rows x 25 columns]

# %%
base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

for index, row in df.iterrows():
    
    caption_info = row['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                    radius = row['Size'], fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)


html = base_map._repr_html_()

file = open("indextest.html","w")
file.write(html)
file.close()

# %%
def condense_duplicates(df):
    
    #df['Popup label'] = pd.Series(dtype='str')
    #df['Size'] = pd.Series(dtype='str')
    
    locations = []
    sizes = []
    droplist = []
    
    for i in range(len(df)):
            
            current_add = df.loc[i, 'Geolocated address']
            number_same = len(df[df['Geolocated address'] == current_add])
            so_far = df[:i]
            is_third = len(so_far[so_far['Geolocated address'] == current_add])
            
            if current_add in locations:
                
                
                    
                    
                    
                
                    droplist.append('yes')
                
                    target_row = df[df['Geolocated address'] == current_add].iloc[number_same//3]
                
                    target_index = df[df['Geolocated address'] == current_add].index.tolist()[0]
                
                    df.loc[target_index, 'Popup label'] += ('<br><br>' + descriptionize(df.iloc[i]))
                
                    df.loc[target_index, 'Size'] += 2
                
                    df.loc[target_index, 'Color'] = 'black'
                
            else:
                droplist.append('no')
                
                df.loc[i, 'Popup label'] = descriptionize(df.iloc[i])
                
                df.loc[i, 'Size'] = 10
                
                if df.loc[i, 'Type'] in colors_dict.keys():
                    df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
                else:
                    df.loc[i, 'Color'] = 'gray'
                    
            
            locations.append(current_add)
            
    df['Drop?'] = droplist
    drop_indexes = df[df['Drop?'] == 'yes'].index.tolist()
    print(drop_indexes)
    df = df.drop(drop_indexes).reset_index()        

    return df

# %%
condense_duplicates(response_df)
# Out:
# [7, 9, 12, 19, 24, 33, 37, 39, 46, 48, 51, 55, 56, 58, 65, 67, 68, 74, 78, 79, 90, 93, 98, 101, 102, 104, 108, 110, 115, 118, 120, 122, 124, 125, 127, 128, 132, 134, 140, 145, 147, 148, 150, 154, 160, 161, 163, 164, 166, 167]
#      index            Timestamp  \
# 0        0    7/9/2021 19:54:13
# 1        1  10/24/2021 16:32:03
# 2        2  10/24/2021 17:07:21
# 3        3  11/11/2021 16:13:49
# 4        4  10/24/2021 14:53:07
# ..     ...                  ...
# 113    157  10/24/2021 17:42:21
# 114    158    7/9/2021 19:58:07
# 115    159  10/23/2021 15:43:53
# 116    162  10/23/2021 14:46:26
# 117    165     7/9/2021 9:10:51
#
#      Name of the place/activity you wish to add to map  \
# 0                         14 Gilbert St Artist Studios
# 1                                  9/11 Memorial Mural
# 2    A Walk Through West Haven: Land Use Coordinati...
# 3                                 Abdul-Razak Zacharia
# 4                                          Abir Zenait
# ..                                                 ...
# 113                                   West Haven Voice
# 114                                    West River Hall
# 115                                       Westies Care
# 116                                   Woodlawn Duckpin
# 117                                    Z's Corner Cafe
#
#                                 Category - What is it?  \
# 0    Visual Arts, Photography, Graphic Design/Print...
# 1                              Visual Arts, Public Art
# 2    Architecture, Culture, Heritage, Tradition, La...
# 3                Literary Arts, Children's Book Author
# 4    Literary Arts, Culinary Arts, Culture, Heritag...
# ..                                                 ...
# 113        Literary Arts, Culture, Heritage, Tradition
# 114                      Event Space, Banquet Facility
# 115  Textile/Apparel, Culinary Arts, Culture, Herit...
# 116  Culture, Heritage, Tradition, Traditional Duck...
# 117                                      Comedy, Music
#
#                                          Type  \
# 0                   Artist(s) Studio/Workshop
# 1                       Landmark/Public Space
# 2    Walking Tour, Maps, Interpretive History
# 3                   Artist(s) Studio/Workshop
# 4                            School/Education
# ..                                        ...
# 113                               Publication
# 114                                  Business
# 115                              Organization
# 116                                  Business
# 117                         Performance Venue
#
#                                   Location  \
# 0       14 Gilbert St West Haven, CT 06516
# 1          245 Elm St West Haven, CT 06516
# 2    676 Campbell Ave West Haven, CT 06516
# 3       304 Center St West Haven, CT 06516
# 4      500 Orange Ave West Haven, CT 06516
# ..                                     ...
# 113    840 Orange Ave West Haven, CT 06516
# 114     37 Orlando St West Haven, CT 06516
# 115     104 Bluff Ave West Haven, CT 06516
# 116     240 Platt Ave West Haven, CT 06516
# 117  407 Campbell Ave West Haven, CT 06516
#
#                                                  Notes  \
# 0                 Property Manager is The Hurley Group
# 1                                 restored in Nov 2020
# 2                                                  NaN
# 3    Children's Book based on growing up in public ...
# 4                                can be hired to tutor
# ..                                                 ...
# 113                                Bill Riccio, Editor
# 114                                                NaN
# 115                             founded by Phil Liscio
# 116  researchers have found references to duckpin b...
# 117                                                NaN
#
#      Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ..                            ...         ...                             ...
# 113                           NaN         NaN                             NaN
# 114                           NaN         NaN                             NaN
# 115                           NaN         NaN                             NaN
# 116                           NaN         NaN                             NaN
# 117                           NaN         NaN                             NaN
#
#      ...         Email Address  \
# 0    ...  artswestct@gmail.com
# 1    ...                   NaN
# 2    ...                   NaN
# 3    ...                   NaN
# 4    ...                   NaN
# ..   ...                   ...
# 113  ...                   NaN
# 114  ...  artswestct@gmail.com
# 115  ...                   NaN
# 116  ...                   NaN
# 117  ...  artswestct@gmail.com
#
#                  What do you love/appreciate about it?  \
# 0    former factory setting with high ceilings enca...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Arabic language, cooking and culture classes a...
# ..                                                 ...
# 113                                                NaN
# 114  Can be rented for special occasions. Somehow s...
# 115                        helping, caring and sharing
# 116  birthday parties, original machines, wooden lanes
# 117                     iconic rock venue for 24 years
#
#                        Website / Social Media Profile? Latitude Longitude  \
# 0                https://www.hurleygroup.net/portfolio  41.2974  -72.9563
# 1    https://us2.campaign-archive.com/?u=389568485a...  41.2766  -72.9504
# 2    https://digitalcommons.law.yale.edu/cgi/viewco...  41.2762  -72.9537
# 3    https://www.google.com/books/edition/The_Night...   41.273  -72.9513
# 4    https://www.linkedin.com/in/zenait-abir-9b9a3a95/  41.2905  -72.9665
# ..                                                 ...      ...       ...
# 113                        https://westhavenvoice.com/  41.2863  -72.9751
# 114                     https://www.westriverhall.com/  41.2997  -72.9551
# 115           https://www.facebook.com/WestiesCare.org  41.2556  -72.9636
# 116                       https://woodlawnduckpin.com/  41.2595  -72.9639
# 117  https://www.facebook.com/Zs-Corner-Cafe-617368...  41.2696  -72.9488
#
#                                     Geolocated address  \
# 0    (14, Gilbert Street, Allingtown, West Haven, N...
# 1    (245, Elm Street, West Haven, New Haven County...
# 2    (676, Campbell Avenue, West Haven, New Haven C...
# 3    (304, Center Street, West Haven, New Haven Cou...
# 4    (500, Orange Avenue, Allingtown, West Haven, N...
# ..                                                 ...
# 113  (840, Orange Avenue, Allingtown, West Haven, N...
# 114  (37, Orlando Street, Allingtown, West Haven, N...
# 115  (104, Bluff Avenue, Sea Bluff, West Haven, New...
# 116  (240, Platt Avenue, Sea Bluff, West Haven, New...
# 117  (407, Campbell Avenue, Savin Rock, West Haven,...
#
#                                            Popup label  Size  Color Drop?
# 0    <b>14 Gilbert St Artist Studios</b> <br> <b>Ca...  12.0  black    no
# 1    <b>9/11 Memorial Mural</b> <br> <b>Category:</...  10.0  green    no
# 2    <b>A Walk Through West Haven: Land Use Coordin...  10.0   gray    no
# 3    <b>Abdul-Razak Zacharia</b> <br> <b>Category:<...  30.0  black    no
# 4    <b>Abir Zenait</b> <br> <b>Category:</b> Liter...  12.0  black    no
# ..                                                 ...   ...    ...   ...
# 113  <b>West Haven Voice</b> <br> <b>Category:</b> ...  10.0   gray    no
# 114  <b>West River Hall</b> <br> <b>Category:</b> E...  10.0   blue    no
# 115  <b>Westies Care</b> <br> <b>Category:</b> Text...  10.0   aqua    no
# 116  <b>Woodlawn Duckpin</b> <br> <b>Category:</b> ...  10.0   blue    no
# 117  <b>Z's Corner Cafe</b> <br> <b>Category:</b> C...  10.0   lime    no
#
# [118 rows x 25 columns]

# %%
#no_dup = condense_duplicates(response_df)

for index, row in .iterrows():
    
    caption_info = row['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                    radius = row['Size'], fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)


html = base_map._repr_html_()

file = open("indextest.html","w")
file.write(html)
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-138b0208d730> in <module>
# ----> 1 no_dup = condense_duplicates(response_df)
#       2
#       3 for index, row in no_dup.iterrows():
#       4
#       5     caption_info = row['Popup label']
#
# NameError: name 'condense_duplicates' is not defined

# %%
df
# Out:
#      index            Timestamp  \
# 0        0    7/9/2021 19:54:13
# 1        1  10/24/2021 16:32:03
# 2        2  10/24/2021 17:07:21
# 3        3  11/11/2021 16:13:49
# 4        4  10/24/2021 14:53:07
# ..     ...                  ...
# 163    163  10/23/2021 23:02:06
# 164    164     7/9/2021 8:32:37
# 165    165     7/9/2021 9:10:51
# 166    166    7/9/2021 19:33:26
# 167    167     7/9/2021 9:44:54
#
#      Name of the place/activity you wish to add to map  \
# 0                         14 Gilbert St Artist Studios
# 1                                  9/11 Memorial Mural
# 2    A Walk Through West Haven: Land Use Coordinati...
# 3                                 Abdul-Razak Zacharia
# 4                                          Abir Zenait
# ..                                                 ...
# 163                                   Yale West Campus
# 164                              Your Queer Plant Shop
# 165                                    Z's Corner Cafe
# 166                                   Zaneta Nicholson
# 167                                      Zohra Rawling
#
#                                 Category - What is it?  \
# 0    Visual Arts, Photography, Graphic Design/Print...
# 1                              Visual Arts, Public Art
# 2    Architecture, Culture, Heritage, Tradition, La...
# 3                Literary Arts, Children's Book Author
# 4    Literary Arts, Culinary Arts, Culture, Heritag...
# ..                                                 ...
# 163                                  Multidisciplinary
# 164  Craft/Design, Culture, Heritage, Tradition, Ho...
# 165                                      Comedy, Music
# 166  Theater Arts, Dance, Culture, Heritage, Tradit...
# 167                            Visual Arts, vaudeville
#
#                                          Type  \
# 0                   Artist(s) Studio/Workshop
# 1                       Landmark/Public Space
# 2    Walking Tour, Maps, Interpretive History
# 3                   Artist(s) Studio/Workshop
# 4                            School/Education
# ..                                        ...
# 163                          School/Education
# 164                                  Business
# 165                         Performance Venue
# 166                 Artist(s) Studio/Workshop
# 167                 Artist(s) Studio/Workshop
#
#                                           Location  \
# 0               14 Gilbert St West Haven, CT 06516
# 1                  245 Elm St West Haven, CT 06516
# 2            676 Campbell Ave West Haven, CT 06516
# 3               304 Center St West Haven, CT 06516
# 4              500 Orange Ave West Haven, CT 06516
# ..                                             ...
# 163        100 West Campus Dr West Haven, CT 06516
# 164             304 Center St West Haven, CT 06516
# 165          407 Campbell Ave West Haven, CT 06516
# 166  243 Captain Thomas Blvd West Haven, CT, 06516
# 167       84 Park Terrace Ave West Haven, CT 06516
#
#                                                  Notes  \
# 0                 Property Manager is The Hurley Group
# 1                                 restored in Nov 2020
# 2                                                  NaN
# 3    Children's Book based on growing up in public ...
# 4                                can be hired to tutor
# ..                                                 ...
# 163    hosted 220+ popup artist studios in 2018 & 2019
# 164  Founded by Anika Stewart and Georgina Marie - ...
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
#
#      Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ..                            ...         ...                             ...
# 163                           NaN         NaN                             NaN
# 164                           NaN         NaN                             NaN
# 165                           NaN         NaN                             NaN
# 166                           NaN         NaN                             NaN
# 167                           NaN         NaN                             NaN
#
#      ...         Email Address  \
# 0    ...  artswestct@gmail.com
# 1    ...                   NaN
# 2    ...                   NaN
# 3    ...                   NaN
# 4    ...                   NaN
# ..   ...                   ...
# 163  ...                   NaN
# 164  ...  artswestct@gmail.com
# 165  ...  artswestct@gmail.com
# 166  ...  artswestct@gmail.com
# 167  ...  artswestct@gmail.com
#
#                  What do you love/appreciate about it?  \
# 0    former factory setting with high ceilings enca...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Arabic language, cooking and culture classes a...
# ..                                                 ...
# 163                                                NaN
# 164   hard-to-find houseplants grown with artisanal...
# 165                     iconic rock venue for 24 years
# 166  recent grad from SCSU theater program with gre...
# 167              evidence of an eclectic creative life
#
#                        Website / Social Media Profile? Latitude Longitude  \
# 0                https://www.hurleygroup.net/portfolio  41.2974  -72.9563
# 1    https://us2.campaign-archive.com/?u=389568485a...  41.2766  -72.9504
# 2    https://digitalcommons.law.yale.edu/cgi/viewco...  41.2762  -72.9537
# 3    https://www.google.com/books/edition/The_Night...   41.273  -72.9513
# 4    https://www.linkedin.com/in/zenait-abir-9b9a3a95/  41.2905  -72.9665
# ..                                                 ...      ...       ...
# 163                       https://westcampus.yale.edu/  41.2614  -72.9866
# 164        https://www.facebook.com/yourqueerplantshop   41.273  -72.9513
# 165  https://www.facebook.com/Zs-Corner-Cafe-617368...  41.2696  -72.9488
# 166          https://www.facebook.com/zaneta.nicholson  41.2601  -72.9465
# 167                                                NaN  41.2625   -72.954
#
#                                     Geolocated address  \
# 0    (14, Gilbert Street, Allingtown, West Haven, N...
# 1    (245, Elm Street, West Haven, New Haven County...
# 2    (676, Campbell Avenue, West Haven, New Haven C...
# 3    (304, Center Street, West Haven, New Haven Cou...
# 4    (500, Orange Avenue, Allingtown, West Haven, N...
# ..                                                 ...
# 163  (West Campus Drive, West Haven, New Haven Coun...
# 164  (304, Center Street, West Haven, New Haven Cou...
# 165  (407, Campbell Avenue, Savin Rock, West Haven,...
# 166  (243, Captain Thomas Boulevard, Savin Rock, We...
# 167  (84, Park Terrace Avenue, Savin Rock, West Hav...
#
#                                            Popup label  Size   Color Drop?
# 0    <b>14 Gilbert St Artist Studios</b> <br> <b>Ca...  10.0  orange    no
# 1    <b>9/11 Memorial Mural</b> <br> <b>Category:</...  10.0   green    no
# 2    <b>A Walk Through West Haven: Land Use Coordin...  10.0    gray    no
# 3    <b>Abdul-Razak Zacharia</b> <br> <b>Category:<...  10.0  orange    no
# 4    <b>Abir Zenait</b> <br> <b>Category:</b> Liter...  10.0    gold    no
# ..                                                 ...   ...     ...   ...
# 163  <b>Yale West Campus</b> <br> <b>Category:</b> ...  10.0    gold    no
# 164  <b>Your Queer Plant Shop</b> <br> <b>Category:...  10.0    blue    no
# 165  <b>Z's Corner Cafe</b> <br> <b>Category:</b> C...  10.0    lime    no
# 166  <b>Zaneta Nicholson</b> <br> <b>Category:</b> ...  10.0  orange    no
# 167  <b>Zohra Rawling</b> <br> <b>Category:</b> Vis...  10.0  orange    no
#
# [168 rows x 25 columns]

# %%
df
# Out:
#      index            Timestamp  \
# 0        0    7/9/2021 19:54:13
# 1        1  10/24/2021 16:32:03
# 2        2  10/24/2021 17:07:21
# 3        3  11/11/2021 16:13:49
# 4        4  10/24/2021 14:53:07
# ..     ...                  ...
# 163    163  10/23/2021 23:02:06
# 164    164     7/9/2021 8:32:37
# 165    165     7/9/2021 9:10:51
# 166    166    7/9/2021 19:33:26
# 167    167     7/9/2021 9:44:54
#
#      Name of the place/activity you wish to add to map  \
# 0                         14 Gilbert St Artist Studios
# 1                                  9/11 Memorial Mural
# 2    A Walk Through West Haven: Land Use Coordinati...
# 3                                 Abdul-Razak Zacharia
# 4                                          Abir Zenait
# ..                                                 ...
# 163                                   Yale West Campus
# 164                              Your Queer Plant Shop
# 165                                    Z's Corner Cafe
# 166                                   Zaneta Nicholson
# 167                                      Zohra Rawling
#
#                                 Category - What is it?  \
# 0    Visual Arts, Photography, Graphic Design/Print...
# 1                              Visual Arts, Public Art
# 2    Architecture, Culture, Heritage, Tradition, La...
# 3                Literary Arts, Children's Book Author
# 4    Literary Arts, Culinary Arts, Culture, Heritag...
# ..                                                 ...
# 163                                  Multidisciplinary
# 164  Craft/Design, Culture, Heritage, Tradition, Ho...
# 165                                      Comedy, Music
# 166  Theater Arts, Dance, Culture, Heritage, Tradit...
# 167                            Visual Arts, vaudeville
#
#                                          Type  \
# 0                   Artist(s) Studio/Workshop
# 1                       Landmark/Public Space
# 2    Walking Tour, Maps, Interpretive History
# 3                   Artist(s) Studio/Workshop
# 4                            School/Education
# ..                                        ...
# 163                          School/Education
# 164                                  Business
# 165                         Performance Venue
# 166                 Artist(s) Studio/Workshop
# 167                 Artist(s) Studio/Workshop
#
#                                           Location  \
# 0               14 Gilbert St West Haven, CT 06516
# 1                  245 Elm St West Haven, CT 06516
# 2            676 Campbell Ave West Haven, CT 06516
# 3               304 Center St West Haven, CT 06516
# 4              500 Orange Ave West Haven, CT 06516
# ..                                             ...
# 163        100 West Campus Dr West Haven, CT 06516
# 164             304 Center St West Haven, CT 06516
# 165          407 Campbell Ave West Haven, CT 06516
# 166  243 Captain Thomas Blvd West Haven, CT, 06516
# 167       84 Park Terrace Ave West Haven, CT 06516
#
#                                                  Notes  \
# 0                 Property Manager is The Hurley Group
# 1                                 restored in Nov 2020
# 2                                                  NaN
# 3    Children's Book based on growing up in public ...
# 4                                can be hired to tutor
# ..                                                 ...
# 163    hosted 220+ popup artist studios in 2018 & 2019
# 164  Founded by Anika Stewart and Georgina Marie - ...
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
#
#      Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ..                            ...         ...                             ...
# 163                           NaN         NaN                             NaN
# 164                           NaN         NaN                             NaN
# 165                           NaN         NaN                             NaN
# 166                           NaN         NaN                             NaN
# 167                           NaN         NaN                             NaN
#
#      ...         Email Address  \
# 0    ...  artswestct@gmail.com
# 1    ...                   NaN
# 2    ...                   NaN
# 3    ...                   NaN
# 4    ...                   NaN
# ..   ...                   ...
# 163  ...                   NaN
# 164  ...  artswestct@gmail.com
# 165  ...  artswestct@gmail.com
# 166  ...  artswestct@gmail.com
# 167  ...  artswestct@gmail.com
#
#                  What do you love/appreciate about it?  \
# 0    former factory setting with high ceilings enca...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4
# 0    Visual Arts, Photography, Graphic Design/Print...
# 1                              Visual Arts, Public Art
# 2    Architecture, Culture, Heritage, Tradition, La...
# 3                Literary Arts, Children's Book Author
# 4    Literary Arts, Culinary Arts, Culture, Heritag...
# ..                                                 ...
# 163                                  Multidisciplinary
# 164  Craft/Design, Culture, Heritage, Tradition, Ho...
# 165                                      Comedy, Music
# 166  Theater Arts, Dance, Culture, Heritage, Tradit...
# 167                            Visual Arts, vaudeville
#
#                                          Type  \
# 0                   Artist(s) Studio/Workshop
# 1                       Landmark/Public Space
# 2    Walking Tour, Maps, Interpretive History
# 3                   Artist(s) Studio/Workshop
# 4                            School/Education
# ..                                        ...
# 163                          School/Education
# 164                                  Business
# 165                         Performance Venue
# 166                 Artist(s) Studio/Workshop
# 167                 Artist(s) Studio/Workshop
#
#                                           Location  \
# 0               14 Gilbert St West Haven, CT 06516
# 1                  245 Elm St West Haven, CT 06516
# 2            676 Campbell Ave West Haven, CT 06516
# 3               304 Center St West Haven, CT 06516
# 4              500 Orange Ave West Haven, CT 06516
# ..                                             ...
# 163        100 West Campus Dr West Haven, CT 06516
# 164             304 Center St West Haven, CT 06516
# 165          407 Campbell Ave West Haven, CT 06516
# 166  243 Captain Thomas Blvd West Haven, CT, 06516
# 167       84 Park Terrace Ave West Haven, CT 06516
#
#                                                  Notes  \
# 0                 Property Manager is The Hurley Group
# 1                                 restored in Nov 2020
# 2                                                  NaN
# 3    Children's Book based on growing up in public ...
# 4                                can be hired to tutor
# ..                                                 ...
# 163    hosted 220+ popup artist studios in 2018 & 2019
# 164  Founded by Anika Stewart and Georgina Marie - ...
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
#
#      Explain "Other," if selected  Unnamed: 7  Explain "Other," if selected.1  \
# 0                             NaN         NaN                             NaN
# 1                             NaN         NaN                             NaN
# 2                             NaN         NaN                             NaN
# 3                             NaN         NaN                             NaN
# 4                             NaN         NaN                             NaN
# ..                            ...         ...                             ...
# 163                           NaN         NaN                             NaN
# 164                           NaN         NaN                             NaN
# 165                           NaN         NaN                             NaN
# 166                           NaN         NaN                             NaN
# 167                           NaN         NaN                             NaN
#
#      Unnamed: 9  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 163         NaN
# 164         NaN
# 165         NaN
# 166         NaN
# 167         NaN
#
#     Upload an image of this place, activity, or brand (optional - legal photos only please. ArtsWestCT may choose to publish for educational, non-commercial purposes but is under no obligation to do so.)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
#
#     Name (first and last)  Address (please be a current West Haven resident)  \
# 0                      NaN                                               NaN
# 1                      NaN                                               NaN
# 2                      NaN                                               NaN
# 3                      NaN                                               NaN
# 4                      NaN                                               NaN
# ..                     ...                                               ...
# 163                    NaN                                               NaN
# 164                    NaN                                               NaN
# 165                    NaN                                               NaN
# 166                    NaN                                               NaN
# 167                    NaN                                               NaN
#
#     Preferred form of contact (text or email)         Email Address  \
# 0                                         NaN  artswestct@gmail.com
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                         NaN                   NaN
# ..                                        ...                   ...
# 163                                       NaN                   NaN
# 164                                       NaN  artswestct@gmail.com
# 165                                       NaN  artswestct@gmail.com
# 166                                       NaN  artswestct@gmail.com
# 167                                       NaN  artswestct@gmail.com
#
#                  What do you love/appreciate about it?  \
# 0    former factory setting with high ceilings enca...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Arabic language, cooking and culture classes a...
# ..                                                 ...
# 163                                                NaN
# 164   hard-to-find houseplants grown with artisanal...
# 165                     iconic rock venue for 24 years
# 166  recent grad from SCSU theater program with gre...
# 167              evidence of an eclectic creative life
#
#                        Website / Social Media Profile? Latitude Longitude  \
# 0                https://www.hurleygroup.net/portfolio  41.2974  -72.9563
# 1    https://us2.campaign-archive.com/?u=389568485a...  41.2766  -72.9504
# 2    https://digitalcommons.law.yale.edu/cgi/viewco...  41.2762  -72.9537
# 3    https://www.google.com/books/edition/The_Night...   41.273  -72.9513
# 4    https://www.linkedin.com/in/zenait-abir-9b9a3a95/  41.2905  -72.9665
# ..                                                 ...      ...       ...
# 163                       https://westcampus.yale.edu/  41.2614  -72.9866
# 164        https://www.facebook.com/yourqueerplantshop   41.273  -72.9513
# 165  https://www.facebook.com/Zs-Corner-Cafe-617368...  41.2696  -72.9488
# 166          https://www.facebook.com/zaneta.nicholson  41.2601  -72.9465
# 167                                                NaN  41.2624   -72.954
#
#                                     Geolocated address
# 0    (14, Gilbert Street, Allingtown, West Haven, N...
# 1    (245, Elm Street, West Haven, New Haven County...
# 2    (676, Campbell Avenue, West Haven, New Haven C...
# 3    (304, Center Street, West Haven, New Haven Cou...
# 4    (500, Orange Avenue, Allingtown, West Haven, N...
# ..                                                 ...
# 163  (West Campus Drive, West Haven, New Haven Coun...
# 164  (304, Center Street, West Haven, New Haven Cou...
# 165  (407, Campbell Avenue, Savin Rock, West Haven,...
# 166  (243, Captain Thomas Boulevard, Savin Rock, We...
# 167  (84, Park Terrace Avenue, Savin Rock, West Hav...
#
# [168 rows x 20 columns]

# %%
import requests
import folium
import pandas as pd
from geopy.geocoders import Nominatim
from flask import Flask

def descriptionize(row):
    
    output = f"<b>{row['Name of the place/activity you wish to add to map']}</b> <br> <b>Category:</b> {row['Category - What is it?']} <br><b>Type:</b> {row['Type']} <br><b>Location:</b> {row['Location']} <br><b>Notes:</b> {row['Notes']}<br> <b>What do you love/appreciate about it?:</b><br>{row['What do you love/appreciate about it?']}"
    return output

def add_categorical_legend(folium_map, title, colors, labels):
    if len(colors) != len(labels):
        raise ValueError("colors and labels must have the same length.")

    color_by_label = dict(zip(labels, colors))
    
    legend_categories = ""     
    for label, color in color_by_label.items():
        legend_categories += f"<li><span style='background:{color}'></span>{label}</li>"
        
    legend_html = f"""
    <div id='maplegend' class='maplegend'>
      <div class='legend-title'>{title}</div>
      <div class='legend-scale'>
        <ul class='legend-labels'>
        {legend_categories}
        </ul>
      </div>
    </div>
    """
    script = f"""
        <script type="text/javascript">
        var oneTimeExecution = (function() {{
                    var executed = false;
                    return function() {{
                        if (!executed) {{
                             var checkExist = setInterval(function() {{
                                       if ((document.getElementsByClassName('leaflet-top leaflet-right').length) || (!executed)) {{
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.display = "flex"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.flexDirection = "column"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].innerHTML += `{legend_html}`;
                                          clearInterval(checkExist);
                                          executed = true;
                                       }}
                                    }}, 100);
                        }}
                    }};
                }})();
        oneTimeExecution()
        </script>
      """
   

    css = """

    <style type='text/css'>
      .maplegend {
        z-index:9999;
        float:right;
        background-color: rgba(255, 255, 255, 1);
        border-radius: 5px;
        border: 2px solid #bbb;
        padding: 10px;
        font-size:12px;
        positon: relative;
      }
      .maplegend .legend-title {
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }
      .maplegend .legend-scale ul {
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }
      .maplegend .legend-scale ul li {
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }
      .maplegend ul.legend-labels li span {
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 0px solid #ccc;
        }
      .maplegend .legend-source {
        font-size: 80%;
        color: #777;
        clear: both;
        }
      .maplegend a {
        color: #777;
        }
    </style>
    """

    folium_map.get_root().header.add_child(folium.Element(script + css))

    return folium_map

'''
# DOWNLOAD DATA FROM GOOGLE SHEET TO LOCAL CSV FILE

url = 'https://docs.google.com/spreadsheets/d/1EyIJRnLrWkeAJuxLVBxO2eSBMfKiQ2aHYLS3PLvQLLs/export?format=csv'
r = requests.get(url, allow_redirects=True)

open('responses.csv', 'wb').write(r.content)
'''

# IMPORT DATASET FROM LOCAL CSV FILE

response_df = pd.read_csv("responses.csv")

geolocator = Nominatim(user_agent="Luke's mapping app", timeout=2)

lat_list = []
long_list = []
add_list = []

for address in response_df['Location']:
    #print(address)
    geo = geolocator.geocode(address)
    if geo != None:
        #print(geo)
        lat = geo.latitude
        long = geo.longitude
        lat_list.append(lat)
        long_list.append(long)
        add_list.append(geo)
    else:
        lat_list.append('41.2705')
        long_list.append('-72.9470')
        add_list.append('West Haven, CT')

response_df.to_csv('coded_responses.csv')

# BREAK UP LARGE LINES OF STRING DATA (for better display in popup)
    
for (columnName, columnData) in response_df.iteritems():
    for row in range(len(columnData)):
        cell = str(columnData.iloc[row])
        count = 0
        overall_count = 0
        if cell == None:
            response_df.at[row, columnName] = ' '
        for char in cell:
            if count >= 50 and char == ' ':
                newstring = cell[:overall_count] + '<br>' + cell[overall_count:]
                response_df.at[row, columnName] = newstring
                cell = newstring
                count = 0
            count +=1
            overall_count += 1
    
response_df['Latitude'] = lat_list
response_df['Longitude'] = long_list
response_df['Geolocated address'] = add_list


# REPLACE NaN VALUES WITH EMPTY STRING


# OFFSET ASSETS AT THE SAME LOCATION

df = response_df.copy()
unique_addresses = df.drop_duplicates(subset = ['Latitude', 'Longitude'])

print(df.equals(unique_addresses))

c = 0.0005
lat_dict = {0: 0, 1: -c, 2: c, 3: 0, 4: 0, 5: -c, 6: -c, 7: c, 8: c, 9: -2*c, 10: 2*c}
long_dict = {0: 0, 1: 0, 2: 0, 3: -c, 4: c, 5: c, 6: c, 7: -c, 8: c, 9: 0, 10: 0}

print(lat_dict)

for index, row in unique_addresses.iterrows():
    #print(row)
    current_lat = row['Latitude']
    current_long = row['Longitude']

    same_loc_df = df.loc[(df['Latitude'] == current_lat) & (df['Longitude'] == current_long)]
    
    if len(same_loc_df) > 1:

        count = 0    
        for index, row in same_loc_df.iterrows():
            #print(index)
            old = float(df.at[index,'Latitude'])
            df.at[index,'Latitude'] = float(df.at[index,'Latitude']) + 0.7*lat_dict[count]
            df.at[index,'Longitude'] = float(df.at[index,'Longitude']) + long_dict[count]
            count += 1

# ASSIGN COLORS TO BUBBLES

colors_dict = {'Organization':              'aqua',
                'Business':                 'blue',
                'Performance Venue':        'lime',
                'Gallery/Museum':           'pink', 
                'School/Education':         'gold',
                'Landmark/Public Space':    'green',
                'Event/Festival':           'red',
                'Artist(s) Studio/Workshop':'orange',
                'House of Worship':         'purple',
                'Library':                  'brown'}

for i in range(len(df)):
    if df.loc[i, 'Type'] in colors_dict.keys():
        df.loc[i, 'Color'] = colors_dict[df.loc[i, 'Type']]
    else:
        df.loc[i, 'Color'] = 'gray'
            
# MAKE THE MAP
            
base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

df.fillna('', inplace=True)

for index, row in df.iterrows():
    
    caption_info = descriptionize(row)#['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                radius = 10, fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)
    
# ADD LEGEND TO MAP

base_map = add_categorical_legend(base_map, 'Asset type',
                             colors = list(colors_dict.values()),
                           labels = list(colors_dict.keys()))
'''
# SAVE MAP TO HTML FILE
        
html = base_map._repr_html_()

file = open("index.html","w")
file.write(html)
file.close()
'''

base_map
# Out:
# False
# {0: 0, 1: -0.0005, 2: 0.0005, 3: 0, 4: 0, 5: -0.0005, 6: -0.0005, 7: 0.0005, 8: 0.0005, 9: -0.001, 10: 0.001}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_395b018b163d442a8d588c6431c37936%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_395b018b163d442a8d588c6431c37936%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_395b018b163d442a8d588c6431c37936%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_395b018b163d442a8d588c6431c37936%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.26%2C%20-72.95%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# SAVE MAP TO HTML FILE
        
html = base_map._repr_html_()

file = open("index.html","w")
file.write(html)
file.close()

# %%
base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

df.fillna('', inplace=True)

for index, row in df.iterrows():
    
    caption_info = descriptionize(row)#['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                radius = 10, fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)

# %%
def add_categorical_legend(folium_map, title, colors, labels):
    if len(colors) != len(labels):
        raise ValueError("colors and labels must have the same length.")

    color_by_label = dict(zip(labels, colors))
    
    legend_categories = ""     
    for label, color in color_by_label.items():
        legend_categories += f"<li><span style='background:{color}'></span>{label}</li>"
        
    legend_html = f"""
    <div id='maplegend' class='maplegend'>
      <div class='legend-title'>{title}</div>
      <div class='legend-scale'>
        <ul class='legend-labels'>
        {legend_categories}
        </ul>
      </div>
    </div>
    """
    script = f"""
        <script type="text/javascript">
        var oneTimeExecution = (function() {{
                    var executed = false;
                    return function() {{
                        if (!executed) {{
                             var checkExist = setInterval(function() {{
                                       if ((document.getElementsByClassName('leaflet-top leaflet-right').length) || (!executed)) {{
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.display = "flex"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.flexDirection = "column"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].innerHTML += `{legend_html}`;
                                          clearInterval(checkExist);
                                          executed = true;
                                       }}
                                    }}, 100);
                        }}
                    }};
                }})();
        oneTimeExecution()
        </script>
      """
   

    css = """

    <style type='text/css'>
      .maplegend {
        z-index:9999;
        float:right;
        background-color: rgba(255, 255, 255, 1);
        border-radius: 5px;
        border: 2px solid #bbb;
        padding: 10px;
        font-size:12px;
        positon: relative;
      }
      .maplegend .legend-title {
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }
      .maplegend .legend-scale ul {
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }
      .maplegend .legend-scale ul li {
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }
      .maplegend ul.legend-labels li span {
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 0px solid #ccc;
        }
      .maplegend .legend-source {
        font-size: 80%;
        color: #777;
        clear: both;
        }
      .maplegend a {
        color: #777;
        }
    </style>
    """

    folium_map.get_root().header.add_child(folium.Element(script + css))

    return folium_map

# %%
base_map = add_categorical_legend(base_map, 'Asset type',
                             colors = list(colors_dict.values()),
                           labels = list(colors_dict.keys()))

# %%
         
base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

df.fillna('', inplace=True)

for index, row in df.iterrows():
    
    caption_info = descriptionize(row)#['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                radius = 10, fill=True, color=row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)
    
# ADD LEGEND TO MAP

base_map = add_categorical_legend(base_map, 'Asset type',
                             colors = list(colors_dict.values()),
                           labels = list(colors_dict.keys()))

# SAVE MAP TO HTML FILE
        
html = base_map._repr_html_()

file = open("index.html","w")
file.write(html)
file.close()


base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%20type%3D%22text/javascript%22%3E%0A%20%20%20%20%20%20%20%20var%20oneTimeExecution%20%3D%20%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20executed%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20return%20function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28%21executed%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20checkExist%20%3D%20setInterval%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28%28document.getElementsByClassName%28%27leaflet-top%20leaflet-right%27%29.length%29%20%7C%7C%20%28%21executed%29%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20document.getElementsByClassName%28%27leaflet-top%20leaflet-right%27%29%5B0%5D.style.display%20%3D%20%22flex%22%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20document.getElementsByClassName%28%27leaflet-top%20leaflet-right%27%29%5B0%5D.style.flexDirection%20%3D%20%22column%22%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20document.getElementsByClassName%28%27leaflet-top%20leaflet-right%27%29%5B0%5D.innerHTML%20%2B%3D%20%60%0A%20%20%20%20%3Cdiv%20id%3D%27maplegend%27%20class%3D%27maplegend%27%3E%0A%20%20%20%20%20%20%3Cdiv%20class%3D%27legend-title%27%3EAsset%20type%3C/div%3E%0A%20%20%20%20%20%20%3Cdiv%20class%3D%27legend-scale%27%3E%0A%20%20%20%20%20%20%20%20%3Cul%20class%3D%27legend-labels%27%3E%0A%20%20%20%20%20%20%20%20%3Cli%3E%3Cspan%20style%3D%27background%3Aaqua%27%3E%3C/span%3EOrganization%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Ablue%27%3E%3C/span%3EBusiness%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Alime%27%3E%3C/span%3EPerformance%20Venue%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Apink%27%3E%3C/span%3EGallery/Museum%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Agold%27%3E%3C/span%3ESchool/Education%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Agreen%27%3E%3C/span%3ELandmark/Public%20Space%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Ared%27%3E%3C/span%3EEvent/Festival%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Aorange%27%3E%3C/span%3EArtist%28s%29%20Studio/Workshop%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Apurple%27%3E%3C/span%3EHouse%20of%20Worship%3C/li%3E%3Cli%3E%3Cspan%20style%3D%27background%3Abrown%27%3E%3C/span%3ELibrary%3C/li%3E%0A%20%20%20%20%20%20%20%20%3C/ul%3E%0A%20%20%20%20%20%20%3C/div%3E%0A%20%20%20%20%3C/div%3E%0A%20%20%20%20%60%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20clearInterval%28checkExist%29%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20executed%20%3D%20true%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%2C%20100%29%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A% ...

# %%
base_map = folium.Map(location=[41.26, -72.95], zoom_start=13.3)

for index, row in df.iterrows():
    
    caption_info = descriptionize(row)#['Popup label']
    
    folium.CircleMarker(
                # Latitude, longitude for each marker
                location=[row['Latitude'], row['Longitude']],
        
                # Size, fill, color of the circle marker
                
                radius = 10, fill=True, color='orange', #row['Color'], #(row['FY18.Max.Population.Count']+1)/25, fill = True, color='orange',
        
                # Text that goes into the popup or tooltip
                tooltip = caption_info 
                  
                 ).add_to(base_map)
    
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f3ef0d6b8894421bb815f6ce05bb01d5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f3ef0d6b8894421bb815f6ce05bb01d5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f3ef0d6b8894421bb815f6ce05bb01d5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f3ef0d6b8894421bb815f6ce05bb01d5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B41.26%2C%20-72.95%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# SAVE MAP TO HTML FILE
        
html = base_map._repr_html_()

file = open("index.html","w")
file.write(html)
file.close()
